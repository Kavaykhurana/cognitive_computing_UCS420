# %% [markdown]
# 1. Take your roll number. Extract its individual digits, and multiply each digit by 10 to form your list L (10
# numbers in list now).
# i. Print L
# ii. iii. iv. v. vi. Add two numbers of your choice to L — one using append() and one using insert() at a specific position.
# Print L after each and explain in a comment what changed.
# Remove two elements from L — one using remove() and one using pop(). Print L after each.
# Sort L in ascending order using sort(), then descending order using sort(reverse=True). Print both.
# Use slicing to print the first three elements and the last three elements of L in a single line each.
# Use list comprehension to create a new list containing only the elements of L that are greater than the
# average of L.

# %%
roll_number = input("Enter your roll number: ") or "1022030789"

L = [int(digit) * 10 for digit in str(roll_number)]

print("Original L:", L)

L.append(100)
print("After append(100):", L)

L.insert(2, 50)
print("After insert(2, 50):", L)

L.remove(100)
print("After remove(100):", L)

L.pop(2)
print("After pop(2):", L)

L.sort()
print("Sorted (Ascending):", L)

L.sort(reverse=True)
print("Sorted (Descending):", L)

print("First three elements:", L[:3])
print("Last three elements:", L[-3:])

average = sum(L) / len(L)
new_list = [x for x in L if x > average]

print("Average of L:", average)
print("Elements greater than average:", new_list)
# Out:
# Original L: [10, 0, 20, 20, 0, 30, 0, 70, 80, 90]
# After append(100): [10, 0, 20, 20, 0, 30, 0, 70, 80, 90, 100]
# After insert(2, 50): [10, 0, 50, 20, 20, 0, 30, 0, 70, 80, 90, 100]
# After remove(100): [10, 0, 50, 20, 20, 0, 30, 0, 70, 80, 90]
# After pop(2): [10, 0, 20, 20, 0, 30, 0, 70, 80, 90]
# Sorted (Ascending): [0, 0, 0, 10, 20, 20, 30, 70, 80, 90]
# Sorted (Descending): [90, 80, 70, 30, 20, 20, 10, 0, 0, 0]
# First three elements: [90, 80, 70]
# Last three elements: [0, 0, 0]
# Average of L: 32.0
# Elements greater than average: [90, 80, 70]

# %% [markdown]
# 2. Create a tuple named scores containing 8 marks: use the first 8 values from your list L in Q1.
# i. ii. Find the highest score and its index in the tuple, and the lowest score and how many times it appears.
# Reverse the tuple and return the result as a list (tuples themselves cannot be reversed in place —
# explain why in a one-line comment, referring to tuple immutability).
# iii. Ask the user to input a score. Print its first occurrence index if present in the tuple, or a not present
# message if not.
# iv. Attempt to change one element of the tuple directly (e.g., scores[0] = 100). Run it, capture the error
# Python raises, and explain in one line why this happens and how it differs from a list.
# v. Unpack the tuple into a first score, a second score, and all remaining scores using the * operator in a
# single line of unpacking.

# %%
scores = tuple(L[:8])
print("Scores tuple:", scores)

highest = max(scores)
lowest = min(scores)

print("Highest score:", highest)
print("Index of highest:", scores.index(highest))
print("Lowest score:", lowest)
print("Occurrences of lowest:", scores.count(lowest))

reversed_scores = list(reversed(scores))
print("Reversed list:", reversed_scores)

user_score_input = input("Enter a score: ")
if user_score_input.isdigit():
    user_score = int(user_score_input)
    if user_score in scores:
        print("First occurrence index:", scores.index(user_score))
    else:
        print("Score not present")
else:
    print("Score not present")

try:
    scores[0] = 100
except TypeError as e:
    print("Captured Error:", e)

first, second, *remaining = scores
print("First score:", first)
print("Second score:", second)
print("Remaining scores:", remaining)
# Out:
# Scores tuple: (90, 80, 70, 30, 20, 20, 10, 0)
# Highest score: 90
# Index of highest: 0
# Lowest score: 0
# Occurrences of lowest: 1
# Reversed list: [0, 10, 20, 20, 30, 70, 80, 90]
# Score not present
# Captured Error: 'tuple' object does not support item assignment
# First score: 90
# Second score: 80
# Remaining scores: [70, 30, 20, 20, 10, 0]

# %% [markdown]
# 3. Set the random seed to your own roll number using random.seed(your_roll_number) before generating
# your numbers — this keeps your list random-looking but reproducible and unique to you (a different seed
# produces a different list, so this cannot be copied from a classmate).
# i. ii. iii. iv. v. Generate a list of 100 random numbers between 100 and 900 (inclusive).
# Count and print all odd numbers in the list.
# Count and print all even numbers in the list.
# Count and print all prime numbers in the list, and additionally build the actual list of prime numbers
# found using list comprehension.
# Print the number that occurs most frequently in your list, and how many times it occurs.

# %%
import random

roll_num_str = str(roll_number) if 'roll_number' in locals() else "1022030789"
random.seed(int(roll_num_str) if roll_num_str.isdigit() else 1022030789)

numbers = [random.randint(100, 900) for _ in range(100)]

odd_numbers = [x for x in numbers if x % 2 != 0]
print("Odd numbers:", odd_numbers)
print("Count of odd numbers:", len(odd_numbers))

even_numbers = [x for x in numbers if x % 2 == 0]
print("Even numbers:", even_numbers)
print("Count of even numbers:", len(even_numbers))

def is_prime(n):
    if n < 2:
        return False
    for i in range(2, int(n ** 0.5) + 1):
        if n % i == 0:
            return False
    return True

prime_numbers = [x for x in numbers if is_prime(x)]

print("Prime numbers:", prime_numbers)
print("Count of prime numbers:", len(prime_numbers))

most_frequent = max(set(numbers), key=numbers.count)

print("Most frequent number:", most_frequent)
print("Occurrences:", numbers.count(most_frequent))
# Out:
# Odd numbers: [867, 297, 857, 437, 291, 711, 397, 527, 889, 705, 845, 227, 179, 287, 669, 121, 635, 455, 733, 457, 375, 831, 185, 427, 841, 581, 759, 847, 155, 331, 647, 137, 547, 853, 121, 767, 639, 465, 665, 305, 543, 897, 547, 833, 345, 861, 551, 529, 633, 711, 655, 279, 341, 433, 849, 707, 169, 535, 435, 263, 485, 597, 587, 165]
# Count of odd numbers: 64
# Even numbers: [466, 582, 708, 562, 328, 604, 540, 334, 788, 690, 238, 244, 642, 768, 430, 250, 160, 502, 108, 540, 524, 334, 376, 484, 680, 374, 324, 398, 748, 492, 126, 384, 200, 236, 360, 424]
# Count of even numbers: 36
# Prime numbers: [857, 397, 227, 179, 733, 457, 331, 647, 137, 547, 853, 547, 433, 263, 587]
# Count of prime numbers: 15
# Most frequent number: 540
# Occurrences: 2

# %% [markdown]
# 4. Using the same 8 digits of your roll number from Q1 (before multiplying by 10), create set A = {digit × 7 for
# each digit} and set B = {digit × 9 for each digit}. Print both sets.
# vi. vii. Find the union of A and B — all unique values across both sets.
# Find the intersection of A and B — values common to both.
# viii. Find A − B and B − A separately (not combined) using difference(), and explain in one line how this
# differs from symmetric_difference().
# ix. x. xi. Find the symmetric difference of A and B.
# Check whether A is a subset of B, and whether B is a superset of A, using issubset() and issuperset().
# Ask the user to input a value X. Remove X from set A if present using discard() (not remove()) — explain
# in one line why discard() is safer than remove() when you're not sure the value exists.

# %%
roll_num_str = str(roll_number) if 'roll_number' in locals() else "1022030789"
digits = [int(digit) for digit in roll_num_str[:8]]

A = {digit * 7 for digit in digits}
B = {digit * 9 for digit in digits}

print("Set A:", A)
print("Set B:", B)

print("Union:", A.union(B))
print("Intersection:", A.intersection(B))

print("A - B:", A.difference(B))
print("B - A:", B.difference(A))

print("Symmetric Difference:", A.symmetric_difference(B))

print("A is subset of B:", A.issubset(B))
print("B is superset of A:", B.issuperset(A))

x_val = input("Enter a value X: ")
if x_val.isdigit():
    X = int(x_val)
    A.discard(X)
    print("Set A after discard:", A)
else:
    print("Set A after discard:", A)
# Out:
# Set A: {0, 7, 14, 49, 21}
# Set B: {0, 9, 18, 27, 63}
# Union: {0, 7, 9, 14, 49, 18, 21, 27, 63}
# Intersection: {0}
# A - B: {49, 21, 14, 7}
# B - A: {9, 18, 27, 63}
# Symmetric Difference: {7, 9, 14, 18, 21, 27, 49, 63}
# A is subset of B: False
# B is superset of A: False
# Set A after discard: {0, 7, 14, 49, 21}

# %% [markdown]
# 5. Consider the following dictionary:
# my_dict = {
# "name": "<your name>",
# "roll_no": "<your roll number>",
# "branch": "<your branch>",
# "age": <your age>,
# "city": "<your home city>"
# }
# i. Rename the key “city” to “location” without changing its value (do not just recreate the dictionary by
# hand — use pop() or dictionary comprehension so the code would work for any dictionary).
# ii. iii. iv. Add a new key “cgpa” with your CGPA as its value.
# Update the value of “age” by increasing it by 1.
# Delete the “branch” key using two different methods in two separate copies of the dictionary: once
# with pop() and once with the del keyword. Explain in one line how pop() differs from del (hint: what
# does each return?).
# v. vi. Iterate over your dictionary using .items() and print each key-value pair as “key → value”.
# Before accessing a key called “email” (which doesn't exist in your dictionary), check for its existence
# using the in keyword and print a safe fallback message instead of letting the program crash.
# vii. Create a second dictionary friend_dict with the same 5 original keys but a friend's (fictional) details.
# Merge it with your own using the {**dict1, **dict2} syntax, and explain in one line which values “win”
# when both dictionaries share a key.
# viii. Use dictionary comprehension to create a new dictionary containing only the key-value pairs from your
# original dictionary where the value is a string.

# %%
my_dict = {
    "name": "Kavay",
    "roll_no": str(roll_number) if 'roll_number' in locals() else "1022030789",
    "branch": "CSE",
    "age": 20,
    "city": "Patiala"
}

my_dict["location"] = my_dict.pop("city")
print("After renaming 'city' to 'location':", my_dict)

my_dict["cgpa"] = 7.89
print("After adding 'cgpa':", my_dict)

my_dict["age"] += 1
print("After incrementing 'age':", my_dict)

dict_pop = my_dict.copy()
dict_del = my_dict.copy()

removed_value = dict_pop.pop("branch")
print("Using pop():", dict_pop)

del dict_del["branch"]
print("Using del:", dict_del)

for key, value in my_dict.items():
    print(f"{key} → {value}")

if "email" in my_dict:
    print("Email:", my_dict["email"])
else:
    print("Email key not found")

friend_dict = {
    "name": "Rahul",
    "roll_no": "1022030999",
    "branch": "CSE",
    "age": 21,
    "city": "Delhi"
}

merged_dict = {**my_dict, **friend_dict}
print("Merged dictionary:", merged_dict)

string_dict = {key: value for key, value in my_dict.items() if isinstance(value, str)}
print("String values:", string_dict)
# Out:
# After renaming 'city' to 'location': {'name': 'Kavay', 'roll_no': '1022030789', 'branch': 'CSE', 'age': 20, 'location': 'Patiala'}
# After adding 'cgpa': {'name': 'Kavay', 'roll_no': '1022030789', 'branch': 'CSE', 'age': 20, 'location': 'Patiala', 'cgpa': 7.89}
# After incrementing 'age': {'name': 'Kavay', 'roll_no': '1022030789', 'branch': 'CSE', 'age': 21, 'location': 'Patiala', 'cgpa': 7.89}
# Using pop(): {'name': 'Kavay', 'roll_no': '1022030789', 'age': 21, 'location': 'Patiala', 'cgpa': 7.89}
# Using del: {'name': 'Kavay', 'roll_no': '1022030789', 'age': 21, 'location': 'Patiala', 'cgpa': 7.89}
# name → Kavay
# roll_no → 1022030789
# branch → CSE
# age → 21
# location → Patiala
# cgpa → 7.89
# Email key not found
# Merged dictionary: {'name': 'Rahul', 'roll_no': '1022030999', 'branch': 'CSE', 'age': 21, 'location': 'Patiala', 'cgpa': 7.89, 'city': 'Delhi'}
# String values: {'name': 'Kavay', 'roll_no': '1022030789', 'branch': 'CSE', 'location': 'Patiala'}
